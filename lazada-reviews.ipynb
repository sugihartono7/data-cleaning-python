# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import numpy as np
import os
import datetime
pd.options.display.max_columns = None

# %%
# encode with utf-8
items = pd.read_csv("lazada reviews/20191002-items.csv", encoding='utf-8')
reviews = pd.read_csv("lazada reviews/20191002-reviews.csv", encoding='utf-8')

# %%
reviews.sample(10)
reviews.shape
# Out:
#            itemId                 category             name  rating  \
# 100864  377474273            beli-smart-tv  Lazada Customer       5
# 126657  160020846        jual-flash-drives          hari P.       5
# 32471   321194529  beli-harddisk-eksternal      Sulistya W.       1
# 78552     7940389  beli-harddisk-eksternal       Zuldian M.       5
# 134250  171506831        jual-flash-drives         Irdan T.       5
# 109916  419320884            beli-smart-tv       Widiastuti       5
# 140358  346370253        jual-flash-drives  Lazada Customer       5
# 58751   419970560  beli-harddisk-eksternal           johari       5
# 30425     2325989  beli-harddisk-eksternal     Rzkyarfsptro       4
# 47293   377474277  beli-harddisk-eksternal        Fadjri R.       5
#
#         originalRating   reviewTitle  \
# 100864             NaN           NaN
# 126657             NaN           NaN
# 32471              NaN           NaN
# 78552              NaN           NaN
# 134250             NaN           NaN
# 109916             NaN           NaN
# 140358             NaN           NaN
# 58751              NaN           NaN
# 30425              NaN  Barang bagus
# 47293              NaN           NaN
#
#                                             reviewContent  likeCount  upVotes  \
# 100864                                                NaN          0        0
# 126657                                       mantappp bos          0        0
# 32471   Lazada yg terhormat, Barang yang kami terima t...          0        0
# 78552                                                 NaN          0        0
# 134250  Barang sudah sampai dengan selamat, mau dicoba...          0        0
# 109916                                                NaN          0        0
# 140358                                                NaN          0        0
# 58751                                                 NaN          0        0
# 30425           Barang bagus tapi pengiriman lumayan lama          0        0
# 47293                                                 NaN          0        0
#
#         downVotes  helpful  relevanceScore   boughtDate  clientType  \
# 100864          0     True           29.83  14 Mei 2019  androidApp
# 126657          0     True           29.51  02 Feb 2019  androidApp
# 32471           0     True           30.26  09 Okt 2018     desktop
# 78552           0     True           19.01  14 Jun 2019  androidApp
# 134250          0     True           24.51  23 Jan 2019  androidApp
# 109916          0     True           19.01  14 Mei 2019  androidApp
# 140358          0     True           44.17  09 Sep 2019  androidApp
# 58751           0     True           22.01  23 Jan 2019  androidApp
# 30425           0     True           22.32  02 Nov 2016  mobile-app
# 47293           0     True           17.01  11 Des 2018  androidApp
#
#        retrievedDate
# 100864    2019-10-02
# 126657    2019-10-02
# 32471     2019-10-02
# 78552     2019-10-02
# 134250    2019-10-02
# 109916    2019-10-02
# 140358    2019-10-02
# 58751     2019-10-02
# 30425     2019-10-02
# 47293     2019-10-02
# (203787, 15)

# %% [markdown]
# # Cleaning data
# ## Missing values

# %%
missing_values_count = reviews.isnull().sum()
missing_values_count
# Out:
# itemId                 0
# category               0
# name                   0
# rating                 0
# originalRating    203779
# reviewTitle       180383
# reviewContent      96758
# likeCount              0
# upVotes                0
# downVotes              0
# helpful                0
# relevanceScore         0
# boughtDate          7107
# clientType             0
# retrievedDate          0
# dtype: int64

# %%
df_missing = pd.DataFrame(missing_values_count, columns=['cnt'])

df_missing['percentage'] = (df_missing['cnt'] / reviews.shape[0]) * 100
df_missing
# Out:
#                    cnt  percentage
# itemId               0    0.000000
# category             0    0.000000
# name                 0    0.000000
# rating               0    0.000000
# originalRating  203779   99.996074
# reviewTitle     180383   88.515460
# reviewContent    96758   47.479967
# likeCount            0    0.000000
# upVotes              0    0.000000
# downVotes            0    0.000000
# helpful              0    0.000000
# relevanceScore       0    0.000000
# boughtDate        7107    3.487465
# clientType           0    0.000000
# retrievedDate        0    0.000000

# %%
# total missing values
total_cells = np.product(reviews.shape)
total_cells
total_missing = missing_values_count.sum()
total_missing
(total_missing/total_cells) * 100
# Out:
# 3056805
# 488027
# 15.965264385526718

# %%
reviews = reviews[reviews.columns.drop(['originalRating', 'reviewTitle'])]
reviews.head()
# Out:
#       itemId                 category             name  rating  \
# 0  100002528  beli-harddisk-eksternal         Kamal U.       5
# 1  100002528  beli-harddisk-eksternal       yofanca m.       4
# 2  100002528  beli-harddisk-eksternal  Lazada Customer       5
# 3  100002528  beli-harddisk-eksternal  Lazada Customer       4
# 4  100002528  beli-harddisk-eksternal         Yosep M.       5
#
#                       reviewContent  likeCount  upVotes  downVotes  helpful  \
# 0   bagus  mantap dah sesui pesanan          0        0          0     True
# 1                Bagus, sesuai foto          0        0          0     True
# 2  okkkkk mantaaaaaaapppp ... goood          0        0          0     True
# 3                      bagus sesuai          0        0          0     True
# 4                               NaN          0        0          0     True
#
#    relevanceScore   boughtDate  clientType retrievedDate
# 0           26.51  09 Apr 2019  androidApp    2019-10-02
# 1           22.49  24 Sep 2017  androidApp    2019-10-02
# 2           21.50  04 Apr 2018  androidApp    2019-10-02
# 3           20.51  22 Sep 2017  androidApp    2019-10-02
# 4           16.01  17 Agu 2018  androidApp    2019-10-02

# %% [markdown]
# # Cleaning data
# ## Clean date types

# %%
reviews.boughtDate.sample(20)
#this data not too important for viewing reviews, maybe only 3% but i think this should not dropped
# Out:
# 19367     27 Mar 2019
# 85100     03 Mei 2019
# 84957     16 Feb 2019
# 186614    13 Des 2017
# 201157    29 Mar 2019
# 115781    30 Agu 2019
# 18850     02 Des 2017
# 48967     16 Feb 2019
# 171107    01 Jul 2019
# 81289     01 Feb 2017
# 6897      28 Mar 2017
# 159567    05 Mar 2019
# 94539     22 Nov 2018
# 156682    06 Mar 2019
# 44467     02 Sep 2019
# 38733     27 Mar 2019
# 138338    14 Des 2017
# 140742    09 Sep 2019
# 52786     08 Sep 2018
# 83978     28 Apr 2019
# Name: boughtDate, dtype: object

# %%
reviews['date_parsed'] = reviews['boughtDate'].str.replace('Mei', 'May')
reviews['date_parsed'] = reviews['date_parsed'].str.replace('Agu', 'Aug')
reviews['date_parsed'] = reviews['date_parsed'].str.replace('Okt', 'Oct')
reviews['date_parsed'] = reviews['date_parsed'].str.replace('Nop', 'Nov')
reviews['date_parsed'] = reviews['date_parsed'].str.replace('Des', 'Dec')

# convert to datetime YMD
reviews['date_parsed'] = pd.to_datetime(reviews['date_parsed'])

# %%
reviews.sample(20)
# Out:
#            itemId                 category             name  rating  \
# 99218   368162161            beli-smart-tv  Lazada Customer       5
# 112217  428575274            beli-smart-tv        Irawan I.       5
# 11784   143669132  beli-harddisk-eksternal        Rahmat A.       4
# 92415   160022809            beli-smart-tv     Lazada Guest       3
# 196412  407406791    shop-televisi-digital         Ahmad S.       5
# 84903   363803836              beli-laptop        Debora M.       5
# 145941  368162165        jual-flash-drives          leli T.       5
# 191880  363646891    shop-televisi-digital          Anna P.       5
# 40490   361124046  beli-harddisk-eksternal  Lazada Customer       5
# 171973  512604347        jual-flash-drives  Lazada Customer       5
# 145429  365810859        jual-flash-drives         Sonia P.       1
# 65029   471620522  beli-harddisk-eksternal        Rahmat A.       5
# 175916    5975849        jual-flash-drives              Ayu       5
# 26689   171506831  beli-harddisk-eksternal        Andrie T.       5
# 45916   377474276  beli-harddisk-eksternal           Aan K.       5
# 138058     278131        jual-flash-drives           DiniJp       5
